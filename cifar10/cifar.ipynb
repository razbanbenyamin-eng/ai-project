# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten
import matplotlib.pyplot as plt

(train_images, train_labels), (test_image, test_labels) = tf.keras.datasets.cifar10.load_data()

train_images = train_images / 255.0
test_image = test_image / 255.0

class_names = ['airplanes', 'cars', 'birds', 'cats', 'deer', 'dogs', 'frogs', 'horses', 'ships', 'trucks']

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(10)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

h = model.fit(train_images, train_labels, epochs=10, validation_data=(test_image, test_labels))

model.evaluate(test_image, test_labels)
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - accuracy: 0.4574 - loss: 1.4942 - val_accuracy: 0.5562 - val_loss: 1.2294
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.5968 - loss: 1.1380 - val_accuracy: 0.6107 - val_loss: 1.0727
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.6522 - loss: 0.9877 - val_accuracy: 0.6468 - val_loss: 1.0156
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.6883 - loss: 0.8898 - val_accuracy: 0.6843 - val_loss: 0.9083
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.7169 - loss: 0.8088 - val_accuracy: 0.6940 - val_loss: 0.9038
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.7378 - loss: 0.7536 - val_accuracy: 0.6777 - val_loss: 0.9532
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.7557 - loss: 0.6977 - val_accuracy: 0.7096 - val_loss: 0.8550
# Epoch 8/10
# ...
