# %%
import tensorflow as tf
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization
from keras.models import Sequential

data = tf.keras.datasets.cifar100
(train_images, train_labels), (test_images, test_labels) = data.load_data()

# نرمال‌سازی داده‌ها (تقسیم بر 255)
train_images = train_images.astype('float32') / 255.0
test_images = test_images.astype('float32') / 255.0

model = Sequential([
    # لایه اول
    Conv2D(64, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3)),
    BatchNormalization(),
    Conv2D(64, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.2),

    # لایه دوم
    Conv2D(128, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    Conv2D(128, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.3),

    # لایه سوم
    Conv2D(256, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.4),

    # لایه فلت و دنس
    Flatten(),
    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(100)
])

model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

h = model.fit(train_images, train_labels, epochs=30, batch_size=64, validation_data=(test_images, test_labels))
# Out:
# Epoch 1/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 201s 254ms/step - accuracy: 0.1371 - loss: 3.9392 - val_accuracy: 0.2388 - val_loss: 3.1657
# Epoch 2/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 207s 265ms/step - accuracy: 0.2970 - loss: 2.8203 - val_accuracy: 0.3487 - val_loss: 2.5615
# Epoch 3/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 206s 263ms/step - accuracy: 0.3873 - loss: 2.3622 - val_accuracy: 0.4254 - val_loss: 2.1461
# Epoch 4/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 205s 263ms/step - accuracy: 0.4358 - loss: 2.1170 - val_accuracy: 0.4062 - val_loss: 2.3432
# Epoch 5/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 206s 263ms/step - accuracy: 0.4719 - loss: 1.9522 - val_accuracy: 0.4948 - val_loss: 1.9047
# Epoch 6/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 206s 264ms/step - accuracy: 0.5021 - loss: 1.8217 - val_accuracy: 0.5093 - val_loss: 1.8273
# Epoch 7/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 206s 263ms/step - accuracy: 0.5317 - loss: 1.6909 - val_accuracy: 0.5109 - val_loss: 1.8527
# Epoch 8/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 206s 263ms/step - accuracy: 0.5530 - loss: 1.5958 - val_accuracy: 0.5289 - val_loss: 1.7721
# Epoch 9/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 205s 263ms/step - accuracy: 0.5734 - loss: 1.5031 - val_accuracy: 0.5613 - val_loss: 1.6030
# Epoch 10/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 207s 264ms/step - accuracy: 0.5899 - loss: 1.4327 - val_accuracy: 0.5701 - val_loss: 1.5555
# Epoch 11/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 206s 264ms/step - accuracy: 0.6103 - loss: 1.3542 - val_accuracy: 0.5654 - val_loss: 1.5740
# Epoch 12/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 209s 267ms/step - accuracy: 0.6251 - loss: 1.2895 - val_accuracy: 0.5938 - val_loss: 1.4733
# Epoch 13/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 206s 264ms/step - accuracy: 0.6385 - loss: 1.2379 - val_accuracy: 0.5796 - val_loss: 1.5252
# Epoch 14/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 205s 262ms/step - accuracy: 0.6479 - loss: 1.1946 - val_accuracy: 0.5831 - val_loss: 1.5569
# Epoch 15/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 206s 263ms/step - accuracy: 0.6656 - loss: 1.1399 - val_accuracy: 0.5963 - val_loss: 1.4869
# Epoch 16/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 206s 264ms/step - accuracy: 0.6729 - loss: 1.1041 - val_accuracy: 0.5936 - val_loss: 1.5050
# Epoch 17/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 206s 263ms/step - accuracy: 0.6843 - loss: 1.0613 - val_accuracy: 0.5962 - val_loss: 1.4783
# Epoch 18/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 206s 264ms/step - accuracy: 0.6918 - loss: 1.0271 - val_accuracy: 0.5637 - val_loss: 1.6691
# Epoch 19/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 206s 264ms/step - accuracy: 0.7004 - loss: 0.9837 - val_accuracy: 0.6012 - val_loss: 1.4891
# Epoch 20/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 207s 264ms/step - accuracy: 0.7131 - loss: 0.9492 - val_accuracy: 0.5821 - val_loss: 1.6170
# Epoch 21/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 206s 264ms/step - accuracy: 0.7144 - loss: 0.9341 - val_accuracy: 0.6158 - val_loss: 1.4137
# Epoch 22/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 206s 263ms/step - accuracy: 0.7230 - loss: 0.9083 - val_accuracy: 0.6100 - val_loss: 1.4799
# Epoch 23/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 206s 264ms/step - accuracy: 0.7303 - loss: 0.8765 - val_accuracy: 0.6101 - val_loss: 1.4602
# Epoch 24/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 206s 264ms/step - accuracy: 0.7356 - loss: 0.8562 - val_accuracy: 0.6157 - val_loss: 1.4597
# Epoch 25/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 206s 263ms/step - accuracy: 0.7410 - loss: 0.8354 - val_accuracy: 0.6091 - val_loss: 1.5000
# Epoch 26/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 206s 264ms/step - accuracy: 0.7498 - loss: 0.8094 - val_accuracy: 0.6207 - val_loss: 1.4663
# Epoch 27/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 206s 264ms/step - accuracy: 0.7520 - loss: 0.8030 - val_accuracy: 0.6161 - val_loss: 1.5005
# Epoch 28/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 206s 264ms/step - accuracy: 0.7609 - loss: 0.7698 - val_accuracy: 0.6311 - val_loss: 1.4246
# Epoch 29/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 207s 265ms/step - accuracy: 0.7661 - loss: 0.7543 - val_accuracy: 0.6186 - val_loss: 1.5049
# Epoch 30/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 206s 264ms/step - accuracy: 0.7692 - loss: 0.7408 - val_accuracy: 0.6291 - val_loss: 1.4349
